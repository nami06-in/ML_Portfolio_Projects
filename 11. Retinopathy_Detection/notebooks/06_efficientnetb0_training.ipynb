# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.metrics import Precision, Recall

from sklearn.utils.class_weight import compute_class_weight

from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay,
    roc_auc_score
)

from sklearn.preprocessing import label_binarize

# %%
TRAIN_DIR = r"E:/ML Portfolio Projects/11. Retinopathy_Detection/data/processed/train"
VAL_DIR = r"E:/ML Portfolio Projects/11. Retinopathy_Detection/data/processed/val"
TEST_DIR = r"E:/ML Portfolio Projects/11. Retinopathy_Detection/data/processed/test"

# %%
IMAGE_SIZE = (224, 224)
BATCH_SIZE = 16

# %%
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,

    rotation_range=15,
    zoom_range=0.10,
    width_shift_range=0.05,
    height_shift_range=0.05,
    brightness_range=[0.9, 1.1],

    horizontal_flip=True
)

val_test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

# %%
train_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

val_generator = val_test_datagen.flow_from_directory(
    VAL_DIR,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

test_generator = val_test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 1234 images belonging to 3 classes.
# Found 265 images belonging to 3 classes.
# Found 265 images belonging to 3 classes.

# %%
# Get training labels
train_labels = train_generator.classes

# Compute balanced class weights
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_labels),
    y=train_labels
)

# Convert to dictionary
class_weights_dict = dict(enumerate(class_weights))

print("Class Weights:")
print(class_weights_dict)
# Out:
# Class Weights:
# {0: np.float64(0.7254556143445032), 1: np.float64(1.033500837520938), 2: np.float64(1.5291201982651796)}

# %%
print(train_generator.class_indices)
# Out:
# {'class_1': 0, 'class_2': 1, 'class_3': 2}

# %%
base_model = EfficientNetB0(
    weights='imagenet',
    include_top=False,
    input_shape=(224, 224, 3)
)

base_model.trainable = False

# %%
x = base_model.output
x = GlobalAveragePooling2D()(x)

x = Dense(128, activation='relu')(x)
x = Dropout(0.5)(x)
output = Dense(3, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)

# %%
model.compile(
    optimizer=Adam(learning_rate=0.00003),
    loss='categorical_crossentropy',
    metrics=[
        'accuracy',
        Precision(name='precision'),
        Recall(name='recall')
    ]
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
checkpoint = ModelCheckpoint(
    filepath=r"E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras",
    monitor='val_loss',
    save_best_only=True,
    mode='min',
    verbose=1
)

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=6,
    restore_best_weights=True
)

lr_reduce = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=3,
    verbose=1
)

# %%
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=40,
    class_weight=class_weights_dict,
    callbacks=[
        checkpoint,
        early_stop,
        lr_reduce
    ]
)
# Out:
# Epoch 1/40
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 873ms/step - accuracy: 0.4705 - loss: 1.0890 - precision: 0.5624 - recall: 0.2551
# Epoch 1: val_loss improved from None to 0.91061, saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
#
# Epoch 1: finished saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 82s 976ms/step - accuracy: 0.5024 - loss: 1.0537 - precision: 0.6099 - recall: 0.2699 - val_accuracy: 0.6302 - val_loss: 0.9106 - val_precision: 0.7957 - val_recall: 0.2792 - learning_rate: 3.0000e-05
# Epoch 2/40
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.5640 - loss: 0.9428 - precision: 0.7045 - recall: 0.3582
# Epoch 2: val_loss improved from 0.91061 to 0.82564, saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
#
# Epoch 2: finished saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 30s 388ms/step - accuracy: 0.5705 - loss: 0.9472 - precision: 0.6940 - recall: 0.3639 - val_accuracy: 0.6566 - val_loss: 0.8256 - val_precision: 0.7955 - val_recall: 0.3962 - learning_rate: 3.0000e-05
# Epoch 3/40
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - accuracy: 0.6329 - loss: 0.8488 - precision: 0.7604 - recall: 0.4388
# Epoch 3: val_loss improved from 0.82564 to 0.76492, saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
#
# Epoch 3: finished saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 27s 345ms/step - accuracy: 0.6345 - loss: 0.8594 - precision: 0.7615 - recall: 0.4425 - val_accuracy: 0.7057 - val_loss: 0.7649 - val_precision: 0.8540 - val_recall: 0.4415 - learning_rate: 3.0000e-05
# Epoch 4/40
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - accuracy: 0.6675 - loss: 0.7988 - precision: 0.7570 - recall: 0.4962
# Epoch 4: val_loss improved from 0.76492 to 0.71539, saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
#
# Epoch 4: finished saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 28s 358ms/step - accuracy: 0.6540 - loss: 0.7901 - precision: 0.7460 - recall: 0.4878 - val_accuracy: 0.7396 - val_loss: 0.7154 - val_precision: 0.8232 - val_recall: 0.5094 - learning_rate: 3.0000e-05
# Epoch 5/40
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.6455 - loss: 0.8056 - precision: 0.7232 - recall: 0.4987
# Epoch 5: val_loss improved from 0.71539 to 0.68377, saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
#
# Epoch 5: finished saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 28s 359ms/step - accuracy: 0.6783 - loss: 0.7689 - precision: 0.7497 - recall: 0.5267 - val_accuracy: 0.7472 - val_loss: 0.6838 - val_precision: 0.8239 - val_recall: 0.5472 - learning_rate: 3.0000e-05
# Epoch 6/40
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 0.7084 - loss: 0.7385 - precision: 0.7699 - recall: 0.5841
# Epoch 6: val_loss improved from 0.68377 to 0.65739, saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
#
# Epoch 6: finished saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 27s 340ms/step - accuracy: 0.6961 - loss: 0.7347 - precision: 0.7634 - recall: 0.5883 - val_accuracy: 0.7547 - val_loss: 0.6574 - val_precision: 0.8333 - val_recall: 0.5849 - learning_rate: 3.0000e-05
# Epoch 7/40
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.7088 - loss: 0.7131 - precision: 0.7732 - recall: 0.5910
# Epoch 7: val_loss improved from 0.65739 to 0.63281, saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
#
# Epoch 7: finished saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 26s 337ms/step - accuracy: 0.7042 - loss: 0.7059 - precision: 0.7707 - recall: 0.6045 - val_accuracy: 0.7623 - val_loss: 0.6328 - val_precision: 0.8247 - val_recall: 0.6038 - learning_rate: 3.0000e-05
# Epoch 8/40
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.6830 - loss: 0.7213 - precision: 0.7592 - recall: 0.5716
# Epoch 8: val_loss improved from 0.63281 to 0.61713, saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
#
# Epoch 8: finished saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 26s 338ms/step - accuracy: 0.7229 - loss: 0.6828 - precision: 0.7829 - recall: 0.6224 - val_accuracy: 0.7811 - val_loss: 0.6171 - val_precision: 0.8232 - val_recall: 0.6151 - learning_rate: 3.0000e-05
# Epoch 9/40
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.7404 - loss: 0.6499 - precision: 0.7919 - recall: 0.6391
# Epoch 9: val_loss improved from 0.61713 to 0.60242, saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
#
# Epoch 9: finished saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 26s 334ms/step - accuracy: 0.7496 - loss: 0.6415 - precision: 0.7954 - recall: 0.6491 - val_accuracy: 0.7698 - val_loss: 0.6024 - val_precision: 0.8309 - val_recall: 0.6491 - learning_rate: 3.0000e-05
# Epoch 10/40
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.7301 - loss: 0.6505 - precision: 0.7964 - recall: 0.6463
# Epoch 10: val_loss improved from 0.60242 to 0.58163, saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
#
# Epoch 10: finished saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 26s 333ms/step - accuracy: 0.7301 - loss: 0.6508 - precision: 0.7866 - recall: 0.6451 - val_accuracy: 0.7811 - val_loss: 0.5816 - val_precision: 0.8404 - val_recall: 0.6755 - learning_rate: 3.0000e-05
# Epoch 11/40
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.7418 - loss: 0.6417 - precision: 0.7779 - recall: 0.6490
# Epoch 11: val_loss improved from 0.58163 to 0.57594, saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
#
# Epoch 11: finished saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 26s 333ms/step - accuracy: 0.7391 - loss: 0.6397 - precision: 0.7778 - recall: 0.6467 - val_accuracy: 0.7736 - val_loss: 0.5759 - val_precision: 0.8295 - val_recall: 0.6792 - learning_rate: 3.0000e-05
# Epoch 12/40
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.7728 - loss: 0.5866 - precision: 0.8190 - recall: 0.6984
# Epoch 12: val_loss improved from 0.57594 to 0.56400, saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
#
# Epoch 12: finished saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 26s 334ms/step - accuracy: 0.7512 - loss: 0.6233 - precision: 0.7964 - recall: 0.6750 - val_accuracy: 0.7925 - val_loss: 0.5640 - val_precision: 0.8214 - val_recall: 0.6943 - learning_rate: 3.0000e-05
# Epoch 13/40
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.7677 - loss: 0.6082 - precision: 0.7981 - recall: 0.6828
# Epoch 13: val_loss improved from 0.56400 to 0.55251, saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
#
# Epoch 13: finished saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 26s 337ms/step - accuracy: 0.7585 - loss: 0.6046 - precision: 0.7949 - recall: 0.6848 - val_accuracy: 0.7962 - val_loss: 0.5525 - val_precision: 0.8304 - val_recall: 0.7019 - learning_rate: 3.0000e-05
# Epoch 14/40
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.7246 - loss: 0.6392 - precision: 0.7604 - recall: 0.6587
# Epoch 14: val_loss improved from 0.55251 to 0.54845, saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
#
# Epoch 14: finished saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 26s 333ms/step - accuracy: 0.7520 - loss: 0.6140 - precision: 0.7797 - recall: 0.6710 - val_accuracy: 0.7962 - val_loss: 0.5485 - val_precision: 0.8202 - val_recall: 0.7057 - learning_rate: 3.0000e-05
# Epoch 15/40
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.7817 - loss: 0.5701 - precision: 0.7988 - recall: 0.7036
# Epoch 15: val_loss improved from 0.54845 to 0.54166, saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
#
# Epoch 15: finished saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 26s 338ms/step - accuracy: 0.7739 - loss: 0.5780 - precision: 0.7983 - recall: 0.7026 - val_accuracy: 0.7925 - val_loss: 0.5417 - val_precision: 0.8238 - val_recall: 0.7057 - learning_rate: 3.0000e-05
# Epoch 16/40
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.7731 - loss: 0.5836 - precision: 0.7939 - recall: 0.7156
# Epoch 16: val_loss improved from 0.54166 to 0.52987, saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
#
# Epoch 16: finished saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 27s 340ms/step - accuracy: 0.7666 - loss: 0.5854 - precision: 0.7927 - recall: 0.7066 - val_accuracy: 0.7962 - val_loss: 0.5299 - val_precision: 0.8398 - val_recall: 0.7321 - learning_rate: 3.0000e-05
# Epoch 17/40
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.7612 - loss: 0.5551 - precision: 0.8030 - recall: 0.7013
# Epoch 17: val_loss improved from 0.52987 to 0.51660, saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
#
# Epoch 17: finished saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 26s 334ms/step - accuracy: 0.7585 - loss: 0.5626 - precision: 0.7976 - recall: 0.7026 - val_accuracy: 0.8113 - val_loss: 0.5166 - val_precision: 0.8419 - val_recall: 0.7434 - learning_rate: 3.0000e-05
# Epoch 18/40
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.7712 - loss: 0.5740 - precision: 0.8072 - recall: 0.7260
# Epoch 18: val_loss improved from 0.51660 to 0.51551, saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
#
# Epoch 18: finished saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 26s 334ms/step - accuracy: 0.7755 - loss: 0.5709 - precision: 0.8057 - recall: 0.7293 - val_accuracy: 0.8075 - val_loss: 0.5155 - val_precision: 0.8435 - val_recall: 0.7321 - learning_rate: 3.0000e-05
# Epoch 19/40
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.7961 - loss: 0.5309 - precision: 0.8321 - recall: 0.7557
# Epoch 19: val_loss improved from 0.51551 to 0.51349, saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
#
# Epoch 19: finished saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 26s 334ms/step - accuracy: 0.7869 - loss: 0.5530 - precision: 0.8141 - recall: 0.7415 - val_accuracy: 0.8038 - val_loss: 0.5135 - val_precision: 0.8369 - val_recall: 0.7358 - learning_rate: 3.0000e-05
# Epoch 20/40
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.7974 - loss: 0.5097 - precision: 0.8346 - recall: 0.7716
# Epoch 20: val_loss improved from 0.51349 to 0.50628, saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
#
# Epoch 20: finished saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 26s 334ms/step - accuracy: 0.7885 - loss: 0.5286 - precision: 0.8183 - recall: 0.7553 - val_accuracy: 0.8113 - val_loss: 0.5063 - val_precision: 0.8291 - val_recall: 0.7321 - learning_rate: 3.0000e-05
# Epoch 21/40
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - accuracy: 0.7943 - loss: 0.5386 - precision: 0.8181 - recall: 0.7526
# Epoch 21: val_loss improved from 0.50628 to 0.49925, saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
#
# Epoch 21: finished saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 26s 335ms/step - accuracy: 0.7836 - loss: 0.5363 - precision: 0.8019 - recall: 0.7447 - val_accuracy: 0.8075 - val_loss: 0.4993 - val_precision: 0.8432 - val_recall: 0.7509 - learning_rate: 3.0000e-05
# Epoch 22/40
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - accuracy: 0.7939 - loss: 0.5314 - precision: 0.8151 - recall: 0.7549
# Epoch 22: val_loss improved from 0.49925 to 0.49607, saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
#
# Epoch 22: finished saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 26s 332ms/step - accuracy: 0.7877 - loss: 0.5406 - precision: 0.8079 - recall: 0.7464 - val_accuracy: 0.8000 - val_loss: 0.4961 - val_precision: 0.8186 - val_recall: 0.7321 - learning_rate: 3.0000e-05
# Epoch 23/40
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - accuracy: 0.7900 - loss: 0.5208 - precision: 0.8121 - recall: 0.7538
# Epoch 23: val_loss improved from 0.49607 to 0.49237, saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
#
# Epoch 23: finished saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 27s 345ms/step - accuracy: 0.7796 - loss: 0.5416 - precision: 0.7986 - recall: 0.7423 - val_accuracy: 0.8075 - val_loss: 0.4924 - val_precision: 0.8235 - val_recall: 0.7396 - learning_rate: 3.0000e-05
# Epoch 24/40
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.8061 - loss: 0.5058 - precision: 0.8179 - recall: 0.7788
# Epoch 24: val_loss improved from 0.49237 to 0.48933, saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
#
# Epoch 24: finished saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 26s 335ms/step - accuracy: 0.8031 - loss: 0.5095 - precision: 0.8206 - recall: 0.7747 - val_accuracy: 0.8075 - val_loss: 0.4893 - val_precision: 0.8340 - val_recall: 0.7585 - learning_rate: 3.0000e-05
# Epoch 25/40
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.7783 - loss: 0.5405 - precision: 0.8167 - recall: 0.7523
# Epoch 25: val_loss improved from 0.48933 to 0.48684, saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
#
# Epoch 25: finished saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 29s 371ms/step - accuracy: 0.7877 - loss: 0.5255 - precision: 0.8155 - recall: 0.7593 - val_accuracy: 0.8113 - val_loss: 0.4868 - val_precision: 0.8292 - val_recall: 0.7509 - learning_rate: 3.0000e-05
# Epoch 26/40
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.8114 - loss: 0.5181 - precision: 0.8274 - recall: 0.7700
# Epoch 26: val_loss improved from 0.48684 to 0.48256, saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
#
# Epoch 26: finished saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 27s 349ms/step - accuracy: 0.8104 - loss: 0.5086 - precision: 0.8248 - recall: 0.7666 - val_accuracy: 0.8151 - val_loss: 0.4826 - val_precision: 0.8272 - val_recall: 0.7585 - learning_rate: 3.0000e-05
# Epoch 27/40
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.7728 - loss: 0.5424 - precision: 0.7975 - recall: 0.7402
# Epoch 27: val_loss improved from 0.48256 to 0.48041, saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
#
# Epoch 27: finished saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 26s 339ms/step - accuracy: 0.7885 - loss: 0.5132 - precision: 0.8193 - recall: 0.7569 - val_accuracy: 0.8151 - val_loss: 0.4804 - val_precision: 0.8347 - val_recall: 0.7623 - learning_rate: 3.0000e-05
# Epoch 28/40
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.8004 - loss: 0.5230 - precision: 0.8210 - recall: 0.7652
# Epoch 28: val_loss improved from 0.48041 to 0.47391, saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
#
# Epoch 28: finished saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 26s 338ms/step - accuracy: 0.8023 - loss: 0.5183 - precision: 0.8250 - recall: 0.7642 - val_accuracy: 0.8189 - val_loss: 0.4739 - val_precision: 0.8354 - val_recall: 0.7660 - learning_rate: 3.0000e-05
# Epoch 29/40
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 0.7928 - loss: 0.5099 - precision: 0.8195 - recall: 0.7637
# Epoch 29: val_loss improved from 0.47391 to 0.47365, saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
#
# Epoch 29: finished saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 27s 339ms/step - accuracy: 0.8096 - loss: 0.4948 - precision: 0.8313 - recall: 0.7788 - val_accuracy: 0.8189 - val_loss: 0.4737 - val_precision: 0.8286 - val_recall: 0.7660 - learning_rate: 3.0000e-05
# Epoch 30/40
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 0.7941 - loss: 0.4919 - precision: 0.8147 - recall: 0.7736
# Epoch 30: val_loss improved from 0.47365 to 0.46525, saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
#
# Epoch 30: finished saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 26s 337ms/step - accuracy: 0.7958 - loss: 0.4921 - precision: 0.8139 - recall: 0.7690 - val_accuracy: 0.8189 - val_loss: 0.4653 - val_precision: 0.8394 - val_recall: 0.7887 - learning_rate: 3.0000e-05
# Epoch 31/40
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 0.8210 - loss: 0.4710 - precision: 0.8383 - recall: 0.7958
# Epoch 31: val_loss improved from 0.46525 to 0.46275, saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
#
# Epoch 31: finished saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 26s 337ms/step - accuracy: 0.8039 - loss: 0.5060 - precision: 0.8152 - recall: 0.7755 - val_accuracy: 0.8302 - val_loss: 0.4627 - val_precision: 0.8529 - val_recall: 0.7660 - learning_rate: 3.0000e-05
# Epoch 32/40
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.7923 - loss: 0.5045 - precision: 0.8082 - recall: 0.7539
# Epoch 32: val_loss did not improve from 0.46275
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 26s 334ms/step - accuracy: 0.7853 - loss: 0.5032 - precision: 0.8035 - recall: 0.7455 - val_accuracy: 0.8151 - val_loss: 0.4737 - val_precision: 0.8382 - val_recall: 0.7623 - learning_rate: 3.0000e-05
# Epoch 33/40
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.8043 - loss: 0.4790 - precision: 0.8264 - recall: 0.7823
# Epoch 33: val_loss improved from 0.46275 to 0.45995, saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
#
# Epoch 33: finished saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 26s 339ms/step - accuracy: 0.8104 - loss: 0.4909 - precision: 0.8291 - recall: 0.7861 - val_accuracy: 0.8340 - val_loss: 0.4599 - val_precision: 0.8529 - val_recall: 0.7660 - learning_rate: 3.0000e-05
# Epoch 34/40
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.8198 - loss: 0.4991 - precision: 0.8313 - recall: 0.7815
# Epoch 34: val_loss did not improve from 0.45995
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 26s 336ms/step - accuracy: 0.8160 - loss: 0.4825 - precision: 0.8289 - recall: 0.7771 - val_accuracy: 0.8151 - val_loss: 0.4646 - val_precision: 0.8458 - val_recall: 0.7660 - learning_rate: 3.0000e-05
# Epoch 35/40
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - accuracy: 0.7897 - loss: 0.5144 - precision: 0.7964 - recall: 0.7700
# Epoch 35: val_loss improved from 0.45995 to 0.44955, saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
#
# Epoch 35: finished saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 26s 335ms/step - accuracy: 0.8071 - loss: 0.4958 - precision: 0.8212 - recall: 0.7853 - val_accuracy: 0.8302 - val_loss: 0.4496 - val_precision: 0.8502 - val_recall: 0.7925 - learning_rate: 3.0000e-05
# Epoch 36/40
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.8051 - loss: 0.4916 - precision: 0.8247 - recall: 0.7869
# Epoch 36: val_loss improved from 0.44955 to 0.44828, saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
#
# Epoch 36: finished saving model to E:/ML Portfolio Projects/11. Retinopathy_Detection/models/efficientnetb0_best.keras
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 26s 338ms/step - accuracy: 0.8047 - loss: 0.4970 - precision: 0.8253 - recall: 0.7812 - val_accuracy: 0.8302 - val_loss: 0.4483 - val_precision: 0.8514 - val_recall: 0.8000 - learning_rate: 3.0000e-05
# Epoch 37/40
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.8127 - loss: 0.4966 - precision: 0.8250 - recall: 0.7822
# Epoch 37: val_loss did not improve from 0.44828
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 26s 332ms/step - accuracy: 0.8152 - loss: 0.4770 - precision: 0.8342 - recall: 0.7869 - val_accuracy: 0.8264 - val_loss: 0.4522 - val_precision: 0.8502 - val_recall: 0.7925 - learning_rate: 3.0000e-05
# Epoch 38/40
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.8014 - loss: 0.4966 - precision: 0.8069 - recall: 0.7740
# Epoch 38: val_loss did not improve from 0.44828
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 26s 335ms/step - accuracy: 0.8177 - loss: 0.4857 - precision: 0.8275 - recall: 0.7893 - val_accuracy: 0.8226 - val_loss: 0.4526 - val_precision: 0.8543 - val_recall: 0.7962 - learning_rate: 3.0000e-05
# Epoch 39/40
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 0.8297 - loss: 0.4428 - precision: 0.8499 - recall: 0.8003
# Epoch 39: val_loss did not improve from 0.44828
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 26s 337ms/step - accuracy: 0.8169 - loss: 0.4721 - precision: 0.8348 - recall: 0.7901 - val_accuracy: 0.8189 - val_loss: 0.4604 - val_precision: 0.8471 - val_recall: 0.7736 - learning_rate: 3.0000e-05
# Epoch 40/40
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.8169 - loss: 0.4657 - precision: 0.8437 - recall: 0.7854
# Epoch 40: val_loss did not improve from 0.44828
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 26s 334ms/step - accuracy: 0.8136 - loss: 0.4697 - precision: 0.8288 - recall: 0.7844 - val_accuracy: 0.8113 - val_loss: 0.4584 - val_precision: 0.8436 - val_recall: 0.7736 - learning_rate: 9.0000e-06

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 5))

# ACCURACY
axes[0].plot(history.history['accuracy'], label='Train Accuracy')
axes[0].plot(history.history['val_accuracy'], label='Validation Accuracy')

axes[0].set_title("Accuracy Curve")
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("Accuracy")
axes[0].legend()


# PRECISION
axes[1].plot(history.history['precision'], label='Train Precision')
axes[1].plot(history.history['val_precision'], label='Validation Precision')

axes[1].set_title("Precision Curve")
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Precision")
axes[1].legend()


# RECALL
axes[2].plot(history.history['recall'], label='Train Recall')
axes[2].plot(history.history['val_recall'], label='Validation Recall')

axes[2].set_title("Recall Curve")
axes[2].set_xlabel("Epoch")
axes[2].set_ylabel("Recall")
axes[2].legend()


plt.tight_layout()
plt.show()

# %%
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')

plt.title("Loss Curve")
plt.xlabel("Epoch")
plt.ylabel("Loss")

plt.legend()
plt.show()

# %%
test_loss, test_accuracy, test_precision, test_recall = model.evaluate(test_generator)

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
print("Test Precision:", test_precision)
print("Test Recall:", test_recall)
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 313ms/step - accuracy: 0.8528 - loss: 0.3874 - precision: 0.8852 - recall: 0.8151
# Test Loss: 0.3873544931411743
# Test Accuracy: 0.852830171585083
# Test Precision: 0.8852459192276001
# Test Recall: 0.8150943517684937

# %%
# Predict probabilities
y_pred_probs = model.predict(test_generator)

# Convert probabilities to predicted classes
y_pred = np.argmax(y_pred_probs, axis=1)

# True labels
y_true = test_generator.classes
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 333ms/step

# %%
print(classification_report(
    y_true,
    y_pred,
    target_names=test_generator.class_indices.keys()
))
# Out:
#               precision    recall  f1-score   support
#
#      class_1       0.94      0.98      0.96       122
#      class_2       0.80      0.73      0.76        86
#      class_3       0.74      0.75      0.75        57
#
#     accuracy                           0.85       265
#    macro avg       0.83      0.82      0.82       265
# weighted avg       0.85      0.85      0.85       265

# %%
cm = confusion_matrix(y_true, y_pred)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=test_generator.class_indices.keys()
)

disp.plot(cmap='Blues')
plt.title("Confusion Matrix")

plt.show()

# %%
# Convert labels to one-hot
y_true_bin = label_binarize(y_true, classes=[0,1,2])

# Compute ROC-AUC
roc_auc = roc_auc_score(
    y_true_bin,
    y_pred_probs,
    multi_class='ovr'
)

print("Multiclass ROC-AUC:", roc_auc)
# Out:
# Multiclass ROC-AUC: 0.954768501546893
